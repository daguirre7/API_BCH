# %% [markdown]
# CALCES DE POSICIÓN EN MONEDA EXTRANJERA (CNBS)

# %%
import requests
import pandas as pd
import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

urlIndicadores= f"https://datos.cnbs.gob.hn/es/api/3/action/datastore_search" 
logo=["FICOHSA","BANCATLAN","BAC CREDOMATIC","BANCOCCI"]
#indicador=["CALCES DE POSICIÓN EN MONEDA EXTRANJERA"]
indicador=["RATIO DE COBERTURA DE LIQUIDEZ"]
#indicador=[""]

for logos in logo:
        params1={
                "resource_id":"509e19c4-09d1-4f3d-9ec4-f7a6e874bb78",  # Recurso de Indicadores
                "filters":{
                        "Logo":logo,
                        "Indicador":indicador
                },
                "limit":1000      
        }
    
    
        responseIndicadores = requests.get(urlIndicadores, json=params1,verify=False)
            
    
        if responseIndicadores.status_code == 200:
                datosIndicadores = responseIndicadores.json()["result"]["records"]
                df_Indicadores=pd.DataFrame(datosIndicadores)
        else:
                print(f"Error {responseIndicadores.status_code}: {responseIndicadores.text}")
else:
    print(f"Error {responseIndicadores.status_code}: {responseIndicadores.text}")     

df_final=df_Indicadores[['FechaReporte','Logo','Indicador','TipoIndicador','Saldo']]
df_final=df_final.rename(columns={
    'FechaReporte':'FECHA',
    'Logo':'BANCO',
    'Indicador':'NOMBRE_INDICADOR',
    'TipoIndicador':'TIPO',
    'Saldo':'VALOR'
})

df_final.sort_values(by='FECHA', ascending=True,inplace=True)
# Out:
# Error 200: {"help": "https://datos.cnbs.gob.hn/es/api/3/action/help_show?name=datastore_search", "success": true, "result": {"filters": {"Logo": ["FICOHSA", "BANCATLAN", "BAC CREDOMATIC", "BANCOCCI"], "Indicador": ["RATIO DE COBERTURA DE LIQUIDEZ"]}, "include_total": true, "limit": 1000, "records_format": "objects", "resource_id": "509e19c4-09d1-4f3d-9ec4-f7a6e874bb78", "total_estimation_threshold": null, "records": [{"_id":394,"Tipo":"01","Inst":"01","TipoInstitucion":"BANCOS COMERCIALES","Logo":"BANCATLAN","FechaReporte":"2024-01-31","Indicador":"RATIO DE COBERTURA DE LIQUIDEZ","TipoIndicador":"5) INDICADORES DE CUMPLIMIENTO","Saldo":133.4485438134966,"Linea":377,"Publicacion":"Si","TipoIndicador_ID":5},{"_id":396,"Tipo":"01","Inst":"03","TipoInstitucion":"BANCOS COMERCIALES","Logo":"BANCOCCI","FechaReporte":"2024-01-31","Indicador":"RATIO DE COBERTURA DE LIQUIDEZ","TipoIndicador":"5) INDICADORES DE CUMPLIMIENTO","Saldo":267.6963374685485,"Linea":377,"Publicacion":"Si","TipoIndicador_ID":5},{"_id":401,"Tipo":"01","Inst":"20","TipoInstitucion":"BANCOS COMERCIALES","Logo":"FICOHSA","FechaReporte":"2024-01-31","Indicador":"RATIO DE COBERTURA DE LIQUIDEZ","TipoIndicador":"5) INDICADORES DE CUMPLIMIENTO","Saldo":125.11879854573952,"Linea":377,"Publicacion":"Si","TipoIndicador_ID":5},{"_id":407,"Tipo":"01","Inst":"31","TipoInstitucion":"BANCOS COMERCIALES","Logo":"BAC CREDOMATIC","FechaReporte":"2024-01-31","Indicador":"RATIO DE COBERTURA DE LIQUIDEZ","TipoIndicador":"5) INDICADORES DE CUMPLIMIENTO","Saldo":140.74744110778906,"Linea":377,"Publicacion":"Si","TipoIndicador_ID":5},{"_id":870,"Tipo":"01","Inst":"01","TipoInstitucion":"BANCOS COMERCIALES","Logo":"BANCATLAN","FechaReporte":"2024-02-29","Indicador":"RATIO DE COBERTURA DE LIQUIDEZ","TipoIndicador":"5) INDICADORES DE CUMPLIMIENTO","Saldo":148.6748516200078,"Linea":377,"Publicacion":"Si","TipoIndicador_ID":5},{"_id":872,"Tipo":"01","Inst":"03","TipoInstitucion":"BANCOS COMERCIALES","Logo":"BANCOCCI","FechaReporte":"2024-02-29","Indicador":"RATIO DE COBERTURA DE LIQUIDEZ","TipoIndicador":"5) INDICADORES DE CUMPLIMIENTO","Saldo":254.43966317026704,"Linea":377,"Publicacion":"Si","TipoIndicador_ID":5},{"_id":877,"Tipo":"01","Inst":"20","TipoInstitucion":"BANCOS COMERCIALES","Logo":"FICOHSA","FechaReporte":"2024-02-29","Indicador":"RATIO DE COBERTURA DE LIQUIDEZ","TipoIndicador":"5) INDICADORES DE CUMPLIMIENTO","Saldo":146.85100488348425,"Linea":377,"Publicacion":"Si","TipoIndicador_ID":5},{"_id":883,"Tipo":"01","Inst":"31","TipoInstitucion":"BANCOS COMERCIALES","Logo":"BAC CREDOMATIC","FechaReporte":"2024-02-29","Indicador":"RATIO DE COBERTURA DE LIQUIDEZ","TipoIndicador":"5) INDICADORES DE CUMPLIMIENTO","Saldo":148.88535951206373,"Linea":377,"Publicacion":"Si","TipoIndicador_ID":5},{"_id":1346,"Tipo":"01","Inst":"01","TipoInstitucion":"BANCOS COMERCIALES","Logo":"BANCATLAN","FechaReporte":"2024-03-31","Indicador":"RATIO DE COBERTURA DE LIQUIDEZ","TipoIndicador":"5) INDICADORES DE CUMPLIMIENTO","Saldo":137.5313163129412,"Linea":377,"Publicacion":"Si","TipoIndicador_ID":5},{"_id":1348,"Tipo":"01","Inst":"03","TipoInstitucion":"BANCOS COMERCIALES","Logo":"BANCOCCI","FechaReporte":"2024-03-31","Indicador":"RATIO DE COBERTURA DE LIQUIDEZ","TipoIndicador":"5) INDICADORES DE CUMPLIMIENTO","Saldo":277.049690055608,"Linea":377,"Publicacion":"Si","TipoIndicador_ID":5},{"_id":1353,"Tipo":"01","Inst":"20","TipoInstitucion":"BANCOS COMERCIALES","Logo":"FICOHSA","FechaReporte":"2024-03-31","Indicador":"RATIO DE COBERTURA DE LIQUIDEZ","TipoIndicador":"5) INDICADORES DE CUMPLIMIENTO","Saldo":135.6412739546592,"Linea":377,"Publicacion":"Si","TipoIndicador_ID":5},{"_id":1359,"Tipo":"01","Inst":"31","TipoInstitucion":"BANCOS COMERCIALES","Logo":"BAC CREDOMATIC","FechaReporte":"2024-03-31","Indicador":"RATIO DE COBERTURA DE LIQUIDEZ","TipoIndicador":"5) INDICADORES DE CUMPLIMIENTO","Saldo":143.4381878434064,"Linea":377,"Publicacion":"Si","TipoIndicador_ID":5},{"_id":1841,"Tipo":"01","Inst":"01"," ...

# %%
df_final.head(10)
# Out:
#          FECHA           BANCO                NOMBRE_INDICADOR  \
# 0   2024-01-31       BANCATLAN  RATIO DE COBERTURA DE LIQUIDEZ
# 1   2024-01-31        BANCOCCI  RATIO DE COBERTURA DE LIQUIDEZ
# 2   2024-01-31         FICOHSA  RATIO DE COBERTURA DE LIQUIDEZ
# 3   2024-01-31  BAC CREDOMATIC  RATIO DE COBERTURA DE LIQUIDEZ
# 4   2024-02-29       BANCATLAN  RATIO DE COBERTURA DE LIQUIDEZ
# 5   2024-02-29        BANCOCCI  RATIO DE COBERTURA DE LIQUIDEZ
# 6   2024-02-29         FICOHSA  RATIO DE COBERTURA DE LIQUIDEZ
# 7   2024-02-29  BAC CREDOMATIC  RATIO DE COBERTURA DE LIQUIDEZ
# 11  2024-03-31  BAC CREDOMATIC  RATIO DE COBERTURA DE LIQUIDEZ
# 10  2024-03-31         FICOHSA  RATIO DE COBERTURA DE LIQUIDEZ
#
#                               TIPO       VALOR
# 0   5) INDICADORES DE CUMPLIMIENTO  133.448544
# 1   5) INDICADORES DE CUMPLIMIENTO  267.696337
# 2   5) INDICADORES DE CUMPLIMIENTO  125.118799
# 3   5) INDICADORES DE CUMPLIMIENTO  140.747441
# 4   5) INDICADORES DE CUMPLIMIENTO  148.674852
# 5   5) INDICADORES DE CUMPLIMIENTO  254.439663
# 6   5) INDICADORES DE CUMPLIMIENTO  146.851005
# 7   5) INDICADORES DE CUMPLIMIENTO  148.885360
# 11  5) INDICADORES DE CUMPLIMIENTO  143.438188
# 10  5) INDICADORES DE CUMPLIMIENTO  135.641274

# %%
df_resultado=df_final.drop_duplicates()
df_resultado.head(10)
# Out:
#          FECHA           BANCO                NOMBRE_INDICADOR  \
# 0   2024-01-31       BANCATLAN  RATIO DE COBERTURA DE LIQUIDEZ
# 1   2024-01-31        BANCOCCI  RATIO DE COBERTURA DE LIQUIDEZ
# 2   2024-01-31         FICOHSA  RATIO DE COBERTURA DE LIQUIDEZ
# 3   2024-01-31  BAC CREDOMATIC  RATIO DE COBERTURA DE LIQUIDEZ
# 4   2024-02-29       BANCATLAN  RATIO DE COBERTURA DE LIQUIDEZ
# 5   2024-02-29        BANCOCCI  RATIO DE COBERTURA DE LIQUIDEZ
# 6   2024-02-29         FICOHSA  RATIO DE COBERTURA DE LIQUIDEZ
# 7   2024-02-29  BAC CREDOMATIC  RATIO DE COBERTURA DE LIQUIDEZ
# 11  2024-03-31  BAC CREDOMATIC  RATIO DE COBERTURA DE LIQUIDEZ
# 10  2024-03-31         FICOHSA  RATIO DE COBERTURA DE LIQUIDEZ
#
#                               TIPO       VALOR
# 0   5) INDICADORES DE CUMPLIMIENTO  133.448544
# 1   5) INDICADORES DE CUMPLIMIENTO  267.696337
# 2   5) INDICADORES DE CUMPLIMIENTO  125.118799
# 3   5) INDICADORES DE CUMPLIMIENTO  140.747441
# 4   5) INDICADORES DE CUMPLIMIENTO  148.674852
# 5   5) INDICADORES DE CUMPLIMIENTO  254.439663
# 6   5) INDICADORES DE CUMPLIMIENTO  146.851005
# 7   5) INDICADORES DE CUMPLIMIENTO  148.885360
# 11  5) INDICADORES DE CUMPLIMIENTO  143.438188
# 10  5) INDICADORES DE CUMPLIMIENTO  135.641274

# %%
################           INSERT TABLE / DATA           #################   #      
from azure.identity import InteractiveBrowserCredential
import pandas as pd
from Server import AZURE
from tqdm import tqdm
from sqlalchemy import create_engine, text

credential = InteractiveBrowserCredential()

server = AZURE
database = 'sqlpooldwhandr01'
schema = 'HN_NAP_HO_MISRIESGOS_F'
tabla = 'CNBS_INDICADORES_FINANCIEROS'
driver = "ODBC Driver 17 for SQL Server"

connection_string = (
        f"DRIVER={driver};"
        f"SERVER={server};"
        f"DATABASE={database};"
        f"Encrypt=yes;"
        f"TrustServerCertificate=no;"
        f"Authentication=ActiveDirectoryInteractive;"
    )

connection_uri = f"mssql+pyodbc:///?odbc_connect={connection_string}"
engine = create_engine(connection_uri, fast_executemany=True)


query = text("""
SELECT COLUMN_NAME, DATA_TYPE , CHARACTER_MAXIMUM_LENGTH
FROM INFORMATION_SCHEMA.COLUMNS 
WHERE TABLE_NAME = :tablita
AND TABLE_SCHEMA = :esquema
""")

with engine.connect() as conn:
    result = conn.execute(query, {"tablita": tabla, "esquema":schema})
    columns_types = {row[0]: [row[1] , row[2]] for row in result}
#columns_types

# %%
#-----------------------------############### INSERT ##################------------------------------------#
#tmp_df = df_cleaned.iloc[:100].copy()


#data_frame = pd.DataFrame(js)
df_resultado['FECHA']=pd.to_datetime(df_resultado['FECHA']).dt.strftime('%Y-%m-%d')
data_frame=df_resultado
chunksize = 100

for start in tqdm(range(0, len(data_frame), chunksize), desc="Insertando datos"):
    end = min(start + chunksize, len(data_frame))
    chunk = data_frame.iloc[start:end]

    try:
        chunk.to_sql(tabla, 
                     con=engine, 
                     schema=schema, 
                     if_exists='append', 
                     index=False, 
                     chunksize=chunksize)
    except Exception as e:
        print(f"Error al insertar datos en la base de datos: {e}")
    #break
print('Proceso de insercion completado')
# Out:
# Insertando datos: 100%|██████████| 1/1 [00:06<00:00,  6.42s/it]
# Proceso de insercion completado
